# %% [markdown]
# В этом ноутбуке содержатся основные этапы разработки системы автоматической классификации злокачественных и доброкачественных новообразований кожи на основе сверточных нейронных сетей. Ссылка на датасет:
# https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000

# %% [markdown]
# Получение данных:

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (1.0.2)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /usr/local/lib/python3.12/dist-packages (from kagglehub) (0.1.37)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (26.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (5.29.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2026.7.22)

# %%
import kagglehub

path = kagglehub.dataset_download("kmader/skin-cancer-mnist-ham10000")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'skin-cancer-mnist-ham10000' dataset.
# Path to dataset files: /kaggle/input/skin-cancer-mnist-ham10000

# %% [markdown]
# Изменение размера изображений:

# %%
import os
import cv2

def preprocess_dataset_simple(source_dir, target_dir, target_folders, target_size=(224, 224)):
    os.makedirs(target_dir, exist_ok=True)
    path_mapping = {}
    counter = 0
    for folder in target_folders:
        current_source_folder = os.path.join(source_dir, folder)
        if not os.path.exists(current_source_folder):
            print(f"Предупреждение: Папка {current_source_folder} не найдена!")
            continue

        for file in os.listdir(current_source_folder):
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.webp')):
                old_path = os.path.join(current_source_folder, file)
                new_path = os.path.join(target_dir, file)
                img = cv2.imread(old_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                if img is None:
                    print(f"Пропущен битый файл: {old_path}")
                    continue

                img_resized = cv2.resize(img, target_size)
                cv2.imwrite(new_path, img_resized, [int(cv2.IMWRITE_JPEG_QUALITY), 95])
                filename_without_ext, _ = os.path.splitext(file)
                path_mapping[filename_without_ext] = new_path
                counter += 1
                if counter % 500 == 0:
                    print(f"Обработано картинок: {counter}")

    print(f"Успешно обработано всего картинок: {counter}")
    return path_mapping

# %%
from pathlib import Path

result_path = Path("/kaggle/working/resized")
result_path.mkdir(parents=True, exist_ok=False)

TARGET_SIZE = (224, 224)
subfolders = ["HAM10000_images_part_1", "HAM10000_images_part_2"]
imageid_path_dict = preprocess_dataset_simple(path, result_path, subfolders, TARGET_SIZE)
# Out:
# Обработано картинок: 500
# Обработано картинок: 1000
# Обработано картинок: 1500
# Обработано картинок: 2000
# Обработано картинок: 2500
# Обработано картинок: 3000
# Обработано картинок: 3500
# Обработано картинок: 4000
# Обработано картинок: 4500
# Обработано картинок: 5000
# Обработано картинок: 5500
# Обработано картинок: 6000
# Обработано картинок: 6500
# Обработано картинок: 7000
# Обработано картинок: 7500
# Обработано картинок: 8000
# Обработано картинок: 8500
# Обработано картинок: 9000
# Обработано картинок: 9500
# Обработано картинок: 10000
# Успешно обработано всего картинок: 10015

# %% [markdown]
# Наименования видов поражения:

# %%
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %% [markdown]
# Таблица признаков и путей к файлам:

# %%
import pandas as pd

skin_df = pd.read_csv(os.path.join(path, 'HAM10000_metadata.csv'))
skin_df['path'] = skin_df['image_id'].map(imageid_path_dict.get)
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get)
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes
skin_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                        path                      cell_type  \
# 0  /kaggle/working/resized/ISIC_0027419.jpg  Benign keratosis-like lesions
# 1  /kaggle/working/resized/ISIC_0025030.jpg  Benign keratosis-like lesions
# 2  /kaggle/working/resized/ISIC_0026769.jpg  Benign keratosis-like lesions
# 3  /kaggle/working/resized/ISIC_0025661.jpg  Benign keratosis-like lesions
# 4  /kaggle/working/resized/ISIC_0031633.jpg  Benign keratosis-like lesions
#
#    cell_type_idx
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2

# %% [markdown]
# Индексы видов поражения:

# %%
leison_type_index_mapping = dict(enumerate(pd.Categorical(skin_df['cell_type']).categories))
leison_type_index_mapping
# Out:
# {0: 'Actinic keratoses',
#  1: 'Basal cell carcinoma',
#  2: 'Benign keratosis-like lesions',
#  3: 'Dermatofibroma',
#  4: 'Melanocytic nevi',
#  5: 'Melanoma',
#  6: 'Vascular lesions'}

# %% [markdown]
# Разведывательный анализ данных:

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(1, 1, figsize= (10, 5))
skin_df['cell_type'].value_counts().plot(kind='bar', ax=ax1)
# Out:
# <Axes: xlabel='cell_type'>

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
skin_df['cell_type_idx'].value_counts().rename(index=leison_type_index_mapping).plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <small>Из гистограммы следует, что в датасете преобладают обычные родинки (melanocytic nevi, 66,9%). Доля остальных 6 классов, в том числе опасных меланом и базальноклеточных карцином невелика (11,1 и 5,1%). Таким образом, для многоклассовой классификации в задаче классификации видов поражения кожи важно корректно определять те именно классы, которые представлены в датасете в небольшом количестве.<small/>

# %%
skin_df['localization'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='localization'>

# %% [markdown]
# <small>В данном исследовании принято решение рассматривать только изображения поражений кожи, не используя дополнительные признаки. Тем не менее, с целью описания исходного датасета ниже представлены некоторые его характеристики. Так, из гистограммы выше видно, что преобладающее расположение родинок - спина, нижние конечности, туловище, верхние конечности, живот, лицо.<small/>

# %%
skin_df['age'].hist(bins=40)
# Out:
# <Axes: >

# %% [markdown]
# <small>В датасете наиболее представлены люди возрастом 40-60 лет.<small/>

# %%
skin_df['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# <small>Женский и мужской пол в датасете представлены примерно поровну.<small/>

# %% [markdown]
# Ниже приведены некоторые примеры изображений различных классов из датасета:

# %%
skin_df['image'] = skin_df['path'].map(lambda x: cv2.resize(cv2.imread(x), (100, 75)))

# %%
n_samples = 5
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs,
                                         skin_df.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)

# %% [markdown]
# Важно отметить, что в датасете одно поражение кожи может быть представлено несколькими фотографиями. Ниже выполнено разбиение на обучающую, валидационную и тестовую выборку так, чтобы одно и то же поражение не попадало в разные группы:

# %%
from sklearn.model_selection import GroupShuffleSplit

gss_test = GroupShuffleSplit(n_splits=1, test_size=0.20, random_state=42)
train_val_idx, test_idx = next(gss_test.split(skin_df, groups=skin_df['lesion_id']))

train_val_df = skin_df.iloc[train_val_idx].reset_index(drop=True)
test_df = skin_df.iloc[test_idx].reset_index(drop=True)

gss_val = GroupShuffleSplit(n_splits=1, test_size=0.20, random_state=42)
train_idx, val_idx = next(gss_val.split(train_val_df, groups=train_val_df['lesion_id']))

train_df = train_val_df.iloc[train_idx].reset_index(drop=True)
val_df = train_val_df.iloc[val_idx].reset_index(drop=True)

print("Пересечение Train и Val:", len(set(train_df['lesion_id']).intersection(set(val_df['lesion_id']))) == 0)
print("Пересечение Train и Test:", len(set(train_df['lesion_id']).intersection(set(test_df['lesion_id']))) == 0)
print("Пересечение Val и Test:", len(set(val_df['lesion_id']).intersection(set(test_df['lesion_id']))) == 0)
# Out:
# Пересечение Train и Val: True
# Пересечение Train и Test: True
# Пересечение Val и Test: True

# %% [markdown]
# Создание генераторов:

# %%
import numpy as np
import tensorflow as tf
from keras.utils import Sequence
from sklearn.model_selection import train_test_split

class ImageDatasetGenerator(Sequence):
    def __init__(self, file_paths, labels, batch_size=32, num_classes=None, shuffle=False):
        self.file_paths = np.array(file_paths)
        self.labels = tf.keras.utils.to_categorical(labels, num_classes=num_classes)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.file_paths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.file_paths) / self.batch_size))

    def __getitem__(self, idx):
        start = idx * self.batch_size
        end = min((idx + 1) * self.batch_size, len(self.file_paths))
        batch_indices = self.indices[start:end]

        batch_x = []
        for file_path in self.file_paths[batch_indices]:
            img = cv2.imread(file_path)

            if img is None:
                raise FileNotFoundError(f"Не удалось прочитать файл: {file_path}")

            img = img.astype(np.float32) / 255.0
            batch_x.append(img)

        batch_x = np.array(batch_x)
        batch_y = self.labels[batch_indices]

        return batch_x, batch_y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# %%
BATCH_SIZE = 32

train_generator = ImageDatasetGenerator(
    file_paths=train_df['path'].values,
    labels=train_df['cell_type_idx'].values, batch_size=BATCH_SIZE, shuffle=True
)

val_generator = ImageDatasetGenerator(
    file_paths=val_df['path'].values,
    labels=val_df['cell_type_idx'].values, batch_size=BATCH_SIZE, shuffle=False
)

test_generator = ImageDatasetGenerator(
    file_paths=test_df['path'].values,
    labels=test_df['cell_type_idx'].values, batch_size=BATCH_SIZE, shuffle=False
)

# %% [markdown]
# Метрики качества:

# %%
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(7, 7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def print_classification_report(y_true, y_pred, target_names):
  print(classification_report(y_true, np.argmax(y_pred, axis=1), target_names=target_names))

def print_results(model, test_generator, target_names):
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(test_generator.labels, axis=1)
    confusion_mtx = confusion_matrix(y_true, y_pred_classes)
    plot_confusion_matrix(confusion_mtx, target_names)
    print_classification_report(y_true, y_pred, target_names)

# %% [markdown]
# Простая CNN-модель:

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, Input, GlobalAveragePooling2D
from keras import backend as K
import itertools
from keras.layers import BatchNormalization

from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split

import math

input_shape = TARGET_SIZE + (3,)
num_classes = 7

model = Sequential()
model.add(Input(shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(GlobalAveragePooling2D())
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,951 (277.15 KB)
#  Trainable params: 70,567 (275.65 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# Коллбэки для уменьшения скорость обучения, когда прогресс замедляется, а также его остановки, когда метрика качества перестает расти:

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

callbacks = [
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        verbose=1,
        min_lr=1e-6
    ),
    EarlyStopping(
        monitor='val_loss',
        mode='min',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
]

# %% [markdown]
# Здесь и далее в моделях в качестве функции потерь используется CategoricalFocalCrossentropy, которая динамически уменьшает вклад легко классифицируемых (уверенных) примеров в общую ошибку, заставляя нейросеть фокусироваться на редких и сложных объектах:

# %%
model.compile(optimizer=Adam(), loss=keras.losses.CategoricalFocalCrossentropy(), metrics=['f1_score', "accuracy"])

model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    callbacks=callbacks,
    verbose = 1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 57s 177ms/step - accuracy: 0.6372 - f1_score: 0.1655 - loss: 0.1609 - val_accuracy: 0.6884 - val_f1_score: 0.1229 - val_loss: 0.1837 - learning_rate: 0.0010
# Epoch 2/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 25s 123ms/step - accuracy: 0.6603 - f1_score: 0.1842 - loss: 0.1399 - val_accuracy: 0.6935 - val_f1_score: 0.2182 - val_loss: 0.1428 - learning_rate: 0.0010
# Epoch 3/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.6655 - f1_score: 0.2120 - loss: 0.1338 - val_accuracy: 0.6612 - val_f1_score: 0.2280 - val_loss: 0.1448 - learning_rate: 0.0010
# Epoch 4/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 27s 134ms/step - accuracy: 0.6692 - f1_score: 0.2070 - loss: 0.1308 - val_accuracy: 0.6498 - val_f1_score: 0.2125 - val_loss: 0.1560 - learning_rate: 0.0010
# Epoch 5/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.6759 - f1_score: 0.2116 - loss: 0.1292 - val_accuracy: 0.6916 - val_f1_score: 0.1527 - val_loss: 0.1364 - learning_rate: 0.0010
# Epoch 6/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 127ms/step - accuracy: 0.6790 - f1_score: 0.2394 - loss: 0.1239 - val_accuracy: 0.6909 - val_f1_score: 0.1817 - val_loss: 0.1464 - learning_rate: 0.0010
# Epoch 7/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 128ms/step - accuracy: 0
100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 129ms/step - accuracy: 0.7442 - f1_score: 0.4695 - loss: 0.0875 - val_accuracy: 0.7536 - val_f1_score: 0.4507 - val_loss: 0.0928 - learning_rate: 1.2500e-04
# Epoch 77/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.7486 - f1_score: 0.4825 - loss: 0.0872 - val_accuracy: 0.7543 - val_f1_score: 0.4256 - val_loss: 0.0904 - learning_rate: 1.2500e-04
# Epoch 78/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - accuracy: 0.7400 - f1_score: 0.4753 - loss: 0.0879 - val_accuracy: 0.7486 - val_f1_score: 0.4464 - val_loss: 0.0919 - learning_rate: 1.2500e-04
# Epoch 79/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - accuracy: 0.7483 - f1_score: 0.4967 - loss: 0.0862 - val_accuracy: 0.7416 - val_f1_score: 0.4159 - val_loss: 0.0938 - learning_rate: 1.2500e-04
# Epoch 80/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7417 - f1_score: 0.4512 - loss: 0.0884
# Epoch 80: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.7475 - f1_score: 0.4775 - loss: 0.0866 - val_accuracy: 0.7416 - val_f1_score: 0.4147 - val_loss: 0.0966 - learning_rate: 1.2500e-04
# Epoch 81/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.7417 - f1_score: 0.4852 - loss: 0.0870 - val_accuracy: 0.7460 - val_f1_score: 0.4035 - val_loss: 0.0976 - learning_rate: 6.2500e-05
# Epoch 82/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - accuracy: 0.7475 - f1_score: 0.4840 - loss: 0.0861 - val_accuracy: 0.7099 - val_f1_score: 0.3760 - val_loss: 0.1078 - learning_rate: 6.2500e-05
# Epoch 83/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 27s 134ms/step - accuracy: 0.7492 - f1_score: 0.4920 - loss: 0.0848 - val_accuracy: 0.7562 - val_f1_score: 0.4254 - val_loss: 0.0910 - learning_rate: 6.2500e-05
# Epoch 84/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 27s 133ms/step - accuracy: 0.7442 - f1_score: 0.4872 - loss: 0.0865 - val_accuracy: 0.7486 - val_f1_score: 0.4135 - val_loss: 0.0920 - learning_rate: 6.2500e-05
# Epoch 85/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 27s 133ms/step - accuracy: 0.7453 - f1_score: 0.4885 - loss: 0.0867 - val_accuracy: 0.7467 - val_f1_score: 0.3878 - val_loss: 0.0983 - learning_rate: 6.2500e-05
# Epoch 86/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - accuracy: 0.7520 - f1_score: 0.4891 - loss: 0.0860 - val_accuracy: 0.7568 - val_f1_score: 0.4247 - val_loss: 0.0911 - learning_rate: 6.2500e-05
# Epoch 87/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.7486 - f1_score: 0.4898 - loss: 0.0856 - val_accuracy: 0.7492 - val_f1_score: 0.4123 - val_loss: 0.0941 - learning_rate: 6.2500e-05
# Epoch 88/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.7417 - f1_score: 0.4630 - loss: 0.0881 - val_accuracy: 0.7403 - val_f1_score: 0.4002 - val_loss: 0.0912 - learning_rate: 6.2500e-05
# Epoch 89/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - accuracy: 0.7481 - f1_score: 0.4801 - loss: 0.0851 - val_accuracy: 0.7549 - val_f1_score: 0.4314 - val_loss: 0.0908 - learning_rate: 6.2500e-05
# Epoch 90/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7497 - f1_score: 0.4993 - loss: 0.0869
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.7445 - f1_score: 0.4889 - loss: 0.0867 - val_accuracy: 0.7536 - val_f1_score: 0.4261 - val_loss: 0.0908 - learning_rate: 6.2500e-05
# Epoch 90: early stopping
# Restoring model weights from the end of the best epoch: 70.

# %%
print_results(model, test_generator, list(leison_type_index_mapping.values()))
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step
#                                precision    recall  f1-score   support
#
#             Actinic keratoses       0.44      0.61      0.51        67
#          Basal cell carcinoma       0.39      0.47      0.42        90
# Benign keratosis-like lesions       0.63      0.37      0.47       243
#                Dermatofibroma       0.50      0.06      0.10        18
#              Melanocytic nevi       0.84      0.93      0.88      1336
#                      Melanoma       0.50      0.35      0.41       236
#              Vascular lesions       0.72      0.53      0.61        34
#
#                      accuracy                           0.75      2024
#                     macro avg       0.57      0.47      0.49      2024
#                  weighted avg       0.74      0.75      0.73      2024

# %% [markdown]
# <small> Из матрицы ошибок видно, что f1-score для простой модели из нескольких сверточных слоев равен 0,49. Обычные родинки классифицируются уверенно с f1 0,88. Опасные меланомы и базальноклеточные карциномы имеют f1 0,41 и 0,42.</small>

# %%
model.save("simple_cnn_model.keras")

# %% [markdown]
# CNN-модель с аугментацией данных:

# %%
from keras.layers import Activation, Input, RandomFlip, RandomRotation, RandomBrightness

model = Sequential()

model.add(Input(shape=input_shape))
model.add(RandomFlip("horizontal_and_vertical"))
model.add(RandomRotation(0.15))

model.add(Conv2D(32, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(GlobalAveragePooling2D())
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 224, 224, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,951 (277.15 KB)
#  Trainable params: 70,567 (275.65 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=keras.losses.CategoricalFocalCrossentropy(), metrics=['f1_score', "accuracy"])

model.fit(
    train_generator,
    validation_data=val_generator,
    batch_size=32,
    epochs=100,
    callbacks=callbacks,
    verbose = 1
)
# Out:
# Epoch 1/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 67s 294ms/step - accuracy: 0.6613 - f1_score: 0.1695 - loss: 0.1477 - val_accuracy: 0.6954 - val_f1_score: 0.1600 - val_loss: 0.1319 - learning_rate: 1.0000e-04
# Epoch 2/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6574 - f1_score: 0.1654 - loss: 0.1440 - val_accuracy: 0.6998 - val_f1_score: 0.1517 - val_loss: 0.1243 - learning_rate: 1.0000e-04
# Epoch 3/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6673 - f1_score: 0.1884 - loss: 0.1380 - val_accuracy: 0.7049 - val_f1_score: 0.2270 - val_loss: 0.1240 - learning_rate: 1.0000e-04
# Epoch 4/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6653 - f1_score: 0.1803 - loss: 0.1365 - val_accuracy: 0.7030 - val_f1_score: 0.1628 - val_loss: 0.1217 - learning_rate: 1.0000e-04
# Epoch 5/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6680 - f1_score: 0.1970 - loss: 0.1350 - val_accuracy: 0.7023 - val_f1_score: 0.2455 - val_loss: 0.1335 - learning_rate: 1.0000e-04
# Epoch 6/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6728 - f1_score: 0.2062 - loss: 0.1318 - val_accuracy: 0.7011 - val_f1_score: 0.1759 - val_loss: 0.1188 - learning_rate: 1.0000e-04
# Epoch 7/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.6728 - f1_score: 0.2013 - loss: 0.1315 - val_accuracy: 0.7144 - val_f1_score: 0.2302 - val_loss: 0.1236 - learning_rate: 1.0000e-04
# Epoch 8/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.6761 - f1_score: 0.2120 - loss: 0.1313 - val_accuracy: 0.7099 - val_f1_score: 0.1936 - val_loss: 0.1176 - learning_rate: 1.0000e-04
# Epoch 9/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 303ms/step - accuracy: 0.6769 - f1_score: 0.2197 - loss: 0.1287 - val_accuracy: 0.7042 - val_f1_score: 0.1730 - val_loss: 0.1157 - learning_rate: 1.0000e-04
# Epoch 10/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6797 - f1_score: 0.2188 - loss: 0.1263 - val_accuracy: 0.7251 - val_f1_score: 0.2520 - val_loss: 0.1118 - learning_rate: 1.0000e-04
# Epoch 11/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.6773 - f1_score: 0.2224 - loss: 0.1284 - val_accuracy: 0.7074 - val_f1_score: 0.2000 - val_loss: 0.1185 - learning_rate: 1.0000e-04
# Epoch 12/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 302ms/step - accuracy: 0.6826 - f1_score: 0.2271 - loss: 0.1250 - val_accuracy: 0.7093 - val_f1_score: 0.2312 - val_loss: 0.1137 - learning_rate: 1.0000e-04
# Epoch 13/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6776 - f1_score: 0.2274 - loss: 0.1255 - val_accuracy: 0.7175 - val_f1_score: 0.2278 - val_loss: 0.1139 - learning_rate: 1.0000e-04
# Epoch 14/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6815 - f1_score: 0.2390 - loss: 0.1245 - val_accuracy: 0.6586 - val_f1_score: 0.2819 - val_loss: 0.1261 - learning_rate: 1.0000e-04
# Epoch 15/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6798 - f1_score: 0.2432 - loss: 0.1237 - val_accuracy: 0.6840 - val_f1_score: 0.2931 - val_loss: 0.1246 - learning_rate: 1.0000e-04
# Epoch 16/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6865 - f1_score: 0.2586 - loss: 0.1222 - val_accuracy: 0.7036 - val_f1_score: 0.1738 - val_loss: 0.1155 - learning_rate: 1.0000e-04
# Epoch 17/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6887 - f1_score: 0.2583 - loss: 0.1216 - val_accuracy: 0.7182 - val_f1_score: 0.2793 - val_loss: 0.1112 - learning_rate: 1.0000e-04
# Epoch 18/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 301ms/step - accuracy: 0.6842 - f1_score: 0.2616 - loss: 0.1220 - val_accuracy: 0.7201 - val_f1_score: 0.2673 - val_loss: 0.1084 - learning_rate: 1.0000e-04
# Epoch 19/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6842 - f1_score: 0.2724 - loss: 0.1210 - val_accuracy: 0.7194 - val_f1_score: 0.2734 - val_loss: 0.1105 - learning_rate: 1.0000e-04
# Epoch 20/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6856 - f1_score: 0.2648 - loss: 0.1190 - val_accuracy: 0.7239 - val_f1_score: 0.3348 - val_loss: 0.1103 - learning_rate: 1.0000e-04
# Epoch 21/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6882 - f1_score: 0.2773 - loss: 0.1183 - val_accuracy: 0.7150 - val_f1_score: 0.2255 - val_loss: 0.1117 - learning_rate: 1.0000e-04
# Epoch 22/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6895 - f1_score: 0.2823 - loss: 0.1191 - val_accuracy: 0.7258 - val_f1_score: 0.3428 - val_loss: 0.1066 - learning_rate: 1.0000e-04
# Epoch 23/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6920 - f1_score: 0.2949 - loss: 0.1188 - val_accuracy: 0.7232 - val_f1_score: 0.2581 - val_loss: 0.1092 - learning_rate: 1.0000e-04
# Epoch 24/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.6900 - f1_score: 0.2839 - loss: 0.1192 - val_accuracy: 0.6852 - val_f1_score: 0.3370 - val_loss: 0.1195 - learning_rate: 1.0000e-04
# Epoch 25/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6912 - f1_score: 0.2956 - loss: 0.1177 - val_accuracy: 0.6808 - val_f1_score: 0.3102 - val_loss: 0.1258 - learning_rate: 1.0000e-04
# Epoch 26/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6934 - f1_score: 0.3023 - loss: 0.1165 - val_accuracy: 0.5826 - val_f1_score: 0.2913 - val_loss: 0.1599 - learning_rate: 1.0000e-04
# Epoch 27/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6992 - f1_score: 0.3071 - loss: 0.1162 - val_accuracy: 0.7163 - val_f1_score: 0.2310 - val_loss: 0.1127 - learning_rate: 1.0000e-04
# Epoch 28/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.6956 - f1_score: 0.3119 - loss: 0.1151 - val_accuracy: 0.7188 - val_f1_score: 0.2718 - val_loss: 0.1066 - learning_rate: 1.0000e-04
# Epoch 29/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.6976 - f1_score: 0.3215 - loss: 0.1154 - val_accuracy: 0.4712 - val_f1_score: 0.2185 - val_loss: 0.1896 - learning_rate: 1.0000e-04
# Epoch 30/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6990 - f1_score: 0.3300 - loss: 0.1148 - val_accuracy: 0.7137 - val_f1_score: 0.2804 - val_loss: 0.1200 - learning_rate: 1.0000e-04
# Epoch 31/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7007 - f1_score: 0.3224 - loss: 0.1148 - val_accuracy: 0.6124 - val_f1_score: 0.3185 - val_loss: 0.1460 - learning_rate: 1.0000e-04
# Epoch 32/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.6964 - f1_score: 0.3067 - loss: 0.1170
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6971 - f1_score: 0.3242 - loss: 0.1145 - val_accuracy: 0.7213 - val_f1_score: 0.3106 - val_loss: 0.1066 - learning_rate: 1.0000e-04
# Epoch 33/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7046 - f1_score: 0.3409 - loss: 0.1121 - val_accuracy: 0.7296 - val_f1_score: 0.3272 - val_loss: 0.1044 - learning_rate: 5.0000e-05
# Epoch 34/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7049 - f1_score: 0.3367 - loss: 0.1120 - val_accuracy: 0.7302 - val_f1_score: 0.3701 - val_loss: 0.1022 - learning_rate: 5.0000e-05
# Epoch 35/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7037 - f1_score: 0.3446 - loss: 0.1113 - val_accuracy: 0.7251 - val_f1_score: 0.3599 - val_loss: 0.1040 - learning_rate: 5.0000e-05
# Epoch 36/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7029 - f1_score: 0.3377 - loss: 0.1123 - val_accuracy: 0.7308 - val_f1_score: 0.3593 - val_loss: 0.1051 - learning_rate: 5.0000e-05
# Epoch 37/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7012 - f1_score: 0.3438 - loss: 0.1114 - val_accuracy: 0.7156 - val_f1_score: 0.3831 - val_loss: 0.1074 - learning_rate: 5.0000e-05
# Epoch 38/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7043 - f1_score: 0.3454 - loss: 0.1113 - val_accuracy: 0.7327 - val_f1_score: 0.3851 - val_loss: 0.1019 - learning_rate: 5.0000e-05
# Epoch 39/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.7084 - f1_score: 0.3478 - loss: 0.1103 - val_accuracy: 0.7232 - val_f1_score: 0.2867 - val_loss: 0.1060 - learning_rate: 5.0000e-05
# Epoch 40/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7065 - f1_score: 0.3484 - loss: 0.1110 - val_accuracy: 0.7232 - val_f1_score: 0.3704 - val_loss: 0.1052 - learning_rate: 5.0000e-05
# Epoch 41/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.7054 - f1_score: 0.3669 - loss: 0.1101 - val_accuracy: 0.7239 - val_f1_score: 0.3303 - val_loss: 0.1070 - learning_rate: 5.0000e-05
# Epoch 42/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7054 - f1_score: 0.3386 - loss: 0.1111 - val_accuracy: 0.7321 - val_f1_score: 0.3729 - val_loss: 0.1015 - learning_rate: 5.0000e-05
# Epoch 43/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7034 - f1_score: 0.3517 - loss: 0.1106 - val_accuracy: 0.7308 - val_f1_score: 0.3806 - val_loss: 0.1026 - learning_rate: 5.0000e-05
# Epoch 44/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.
100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.7137 - f1_score: 0.3773 - loss: 0.1059 - val_accuracy: 0.7346 - val_f1_score: 0.3473 - val_loss: 0.0982 - learning_rate: 2.5000e-05
# Epoch 61/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.7204 - f1_score: 0.3798 - loss: 0.1058 - val_accuracy: 0.7308 - val_f1_score: 0.3450 - val_loss: 0.0993 - learning_rate: 2.5000e-05
# Epoch 62/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7110 - f1_score: 0.3633 - loss: 0.1053 - val_accuracy: 0.7378 - val_f1_score: 0.4025 - val_loss: 0.1006 - learning_rate: 2.5000e-05
# Epoch 63/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7174 - f1_score: 0.3844 - loss: 0.1054 - val_accuracy: 0.7384 - val_f1_score: 0.3683 - val_loss: 0.0990 - learning_rate: 2.5000e-05
# Epoch 64/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7202 - f1_score: 0.3856 - loss: 0.1064 - val_accuracy: 0.7422 - val_f1_score: 0.3848 - val_loss: 0.0991 - learning_rate: 2.5000e-05
# Epoch 65/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.7176 - f1_score: 0.3855 - loss: 0.1040 - val_accuracy: 0.7251 - val_f1_score: 0.4143 - val_loss: 0.1031 - learning_rate: 2.5000e-05
# Epoch 66/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.7074 - f1_score: 0.3606 - loss: 0.1061 - val_accuracy: 0.7340 - val_f1_score: 0.4111 - val_loss: 0.0999 - learning_rate: 2.5000e-05
# Epoch 67/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7194 - f1_score: 0.3911 - loss: 0.1040 - val_accuracy: 0.7264 - val_f1_score: 0.3994 - val_loss: 0.0997 - learning_rate: 2.5000e-05
# Epoch 68/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.7191 - f1_score: 0.3755 - loss: 0.1043 - val_accuracy: 0.7277 - val_f1_score: 0.3437 - val_loss: 0.1009 - learning_rate: 2.5000e-05
# Epoch 69/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7160 - f1_score: 0.3686 - loss: 0.1061 - val_accuracy: 0.7416 - val_f1_score: 0.3926 - val_loss: 0.0977 - learning_rate: 2.5000e-05
# Epoch 70/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7177 - f1_score: 0.3789 - loss: 0.1042 - val_accuracy: 0.7378 - val_f1_score: 0.3676 - val_loss: 0.0985 - learning_rate: 2.5000e-05
# Epoch 71/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7210 - f1_score: 0.3944 - loss: 0.1035 - val_accuracy: 0.7410 - val_f1_score: 0.3637 - val_loss: 0.0980 - learning_rate: 2.5000e-05
# Epoch 72/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7135 - f1_score: 0.3745 - loss: 0.1062 - val_accuracy: 0.7435 - val_f1_score: 0.3860 - val_loss: 0.0983 - learning_rate: 2.5000e-05
# Epoch 73/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 302ms/step - accuracy: 0.7154 - f1_score: 0.3746 - loss: 0.1049 - val_accuracy: 0.7353 - val_f1_score: 0.3755 - val_loss: 0.0985 - learning_rate: 2.5000e-05
# Epoch 74/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7180 - f1_score: 0.3864 - loss: 0.1041 - val_accuracy: 0.7327 - val_f1_score: 0.3374 - val_loss: 0.1016 - learning_rate: 2.5000e-05
# Epoch 75/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7176 - f1_score: 0.3694 - loss: 0.1038 - val_accuracy: 0.7429 - val_f1_score: 0.3926 - val_loss: 0.0976 - learning_rate: 2.5000e-05
# Epoch 76/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 303ms/step - accuracy: 0.7165 - f1_score: 0.3820 - loss: 0.1047 - val_accuracy: 0.7251 - val_f1_score: 0.4198 - val_loss: 0.1020 - learning_rate: 2.5000e-05
# Epoch 77/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.7244 - f1_score: 0.3971 - loss: 0.1039 - val_accuracy: 0.7429 - val_f1_score: 0.3986 - val_loss: 0.0986 - learning_rate: 2.5000e-05
# Epoch 78/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 302ms/step - accuracy: 0.7130 - f1_score: 0.3770 - loss: 0.1044 - val_accuracy: 0.7359 - val_f1_score: 0.3445 - val_loss: 0.0995 - learning_rate: 2.5000e-05
# Epoch 79/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.7162 - f1_score: 0.3762 - loss: 0.1061 - val_accuracy: 0.7340 - val_f1_score: 0.3425 - val_loss: 0.0989 - learning_rate: 2.5000e-05
# Epoch 80/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7188 - f1_score: 0.3918 - loss: 0.1029 - val_accuracy: 0.7277 - val_f1_score: 0.3075 - val_loss: 0.1055 - learning_rate: 2.5000e-05
# Epoch 81/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7135 - f1_score: 0.3733 - loss: 0.1046 - val_accuracy: 0.7429 - val_f1_score: 0.4148 - val_loss: 0.0993 - learning_rate: 2.5000e-05
# Epoch 82/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.7129 - f1_score: 0.3755 - loss: 0.1038 - val_accuracy: 0.7378 - val_f1_score: 0.3749 - val_loss: 0.0974 - learning_rate: 2.5000e-05
# Epoch 83/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.7208 - f1_score: 0.3944 - loss: 0.1032 - val_accuracy: 0.7448 - val_f1_score: 0.3812 - val_loss: 0.0972 - learning_rate: 2.5000e-05
# Epoch 84/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 61s 302ms/step - accuracy: 0.7157 - f1_score: 0.3843 - loss: 0.1042 - val_accuracy: 0.7346 - val_f1_score: 0.3502 - val_loss: 0.0995 - learning_rate: 2.5000e-05
# Epoch 85/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.7197 - f1_score: 0.3804 - loss: 0.1042 - val_accuracy: 0.7251 - val_f1_score: 0.4110 - val_loss: 0.1011 - learning_rate: 2.5000e-05
# Epoch 86/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.7210 - f1_score: 0.3971 - loss: 0.1038 - val_accuracy: 0.7416 - val_f1_score: 0.3840 - val_loss: 0.0991 - learning_rate: 2.5000e-05
# Epoch 87/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7183 - f1_score: 0.3878 - loss: 0.1045 - val_accuracy: 0.7378 - val_f1_score: 0.3737 - val_loss: 0.0977 - learning_rate: 2.5000e-05
# Epoch 88/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.7180 - f1_score: 0.3899 - loss: 0.1037 - val_accuracy: 0.7403 - val_f1_score: 0.3843 - val_loss: 0.0968 - learning_rate: 2.5000e-05
# Epoch 89/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 60s 301ms/step - accuracy: 0.7183 - f1_score: 0.3723 - loss: 0.1044 - val_accuracy: 0.7391 - val_f1_score: 0.3593 - val_loss: 0.0977 - learning_rate: 2.5000e-05
# Epoch 90/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7224 - f1_score: 0.3902 - loss: 0.1031 - val_accuracy: 0.7365 - val_f1_score: 0.4128 - val_loss: 0.0995 - learning_rate: 2.5000e-05
# Epoch 91/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7182 - f1_score: 0.3946 - loss: 0.1025 - val_accuracy: 0.7435 - val_f1_score: 0.3945 - val_loss: 0.0976 - learning_rate: 2.5000e-05
# Epoch 92/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7288 - f1_score: 0.4155 - loss: 0.1033 - val_accuracy: 0.7321 - val_f1_score: 0.3146 - val_loss: 0.1003 - learning_rate: 2.5000e-05
# Epoch 93/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.7224 - f1_score: 0.3830 - loss: 0.1034 - val_accuracy: 0.7422 - val_f1_score: 0.3651 - val_loss: 0.0973 - learning_rate: 2.5000e-05
# Epoch 94/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7255 - f1_score: 0.3988 - loss: 0.1032 - val_accuracy: 0.7359 - val_f1_score: 0.3789 - val_loss: 0.0970 - learning_rate: 2.5000e-05
# Epoch 95/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.7187 - f1_score: 0.3907 - loss: 0.1039 - val_accuracy: 0.7340 - val_f1_score: 0.3552 - val_loss: 0.0983 - learning_rate: 2.5000e-05
# Epoch 96/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7226 - f1_score: 0.4030 - loss: 0.1025 - val_accuracy: 0.7397 - val_f1_score: 0.3563 - val_loss: 0.0974 - learning_rate: 2.5000e-05
# Epoch 97/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7244 - f1_score: 0.3964 - loss: 0.1025 - val_accuracy: 0.7239 - val_f1_score: 0.3989 - val_loss: 0.1049 - learning_rate: 2.5000e-05
# Epoch 98/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7213 - f1_score: 0.3936 - loss: 0.1013 - val_accuracy: 0.7429 - val_f1_score: 0.3841 - val_loss: 0.0963 - learning_rate: 2.5000e-05
# Epoch 99/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7254 - f1_score: 0.4062 - loss: 0.1008 - val_accuracy: 0.7391 - val_f1_score: 0.3606 - val_loss: 0.0994 - learning_rate: 2.5000e-05
# Epoch 100/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7269 - f1_score: 0.3931 - loss: 0.1023 - val_accuracy: 0.7397 - val_f1_score: 0.3716 - val_loss: 0.0987 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 98.

# %%
print_results(model, test_generator, list(leison_type_index_mapping.values()))
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                precision    recall  f1-score   support
#
#             Actinic keratoses       0.47      0.43      0.45        67
#          Basal cell carcinoma       0.37      0.31      0.34        90
# Benign keratosis-like lesions       0.52      0.38      0.44       243
#                Dermatofibroma       0.00      0.00      0.00        18
#              Melanocytic nevi       0.81      0.94      0.87      1336
#                      Melanoma       0.49      0.33      0.40       236
#              Vascular lesions       0.50      0.06      0.11        34
#
#                      accuracy                           0.73      2024
#                     macro avg       0.45      0.35      0.37      2024
#                  weighted avg       0.70      0.73      0.70      2024

# %% [markdown]
# <small> Оказалось, что для простой модели аугментация изображений не позволила улучшить качество. Наоборот, наблюдается даже небольшое снижение значений метрики f1 как для обычных родинок, так и для опасных классов. Изучение причин данного явления требует отдельного исследования и выходит за рамки данной работы.</small>

# %%
model.save("augmentation_cnn_model.keras")

# %% [markdown]
# Модель CNN с переносом обучения:

# %%
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.layers import GlobalAveragePooling2D, Lambda
from keras.applications.densenet import preprocess_input as dense_preprocess

model = Sequential()

model.add(Input(shape=input_shape))
model.add(RandomFlip("horizontal_and_vertical"))
model.add(RandomRotation(0.15))

model.add(Lambda(lambda x: preprocess_input(x * 255.0))),

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.trainable = False
model.add(base_model)

model.add(GlobalAveragePooling2D())
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_1 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_1               │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 7)              │        14,343 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,602,055 (90.03 MB)
#  Trainable params: 14,343 (56.03 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=keras.losses.CategoricalFocalCrossentropy(), metrics=['f1_score', "accuracy"])

model.fit(
    train_generator,
    validation_data=val_generator,
    batch_size=32,
    epochs=100,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.5301 - f1_score: 0.1650 - loss: 0.2613 - val_accuracy: 0.6846 - val_f1_score: 0.1680 - val_loss: 0.1650 - learning_rate: 1.0000e-04
# Epoch 2/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 35s 172ms/step - accuracy: 0.6411 - f1_score: 0.2335 - loss: 0.1759 - val_accuracy: 0.7017 - val_f1_score: 0.2178 - val_loss: 0.1371 - learning_rate: 1.0000e-04
# Epoch 3/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.6680 - f1_score: 0.2837 - loss: 0.1511 - val_accuracy: 0.7182 - val_f1_score: 0.2685 - val_loss: 0.1235 - learning_rate: 1.0000e-04
# Epoch 4/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.6822 - f1_score: 0.3282 - loss: 0.1360 - val_accuracy: 0.7258 - val_f1_score: 0.3021 - val_loss: 0.1145 - learning_rate: 1.0000e-04
# Epoch 5/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.6951 - f1_score: 0.3550 - loss: 0.1276 - val_accuracy: 0.7372 - val_f1_score: 0.3333 - val_loss: 0.1121 - learning_rate: 1.0000e-04
# Epoch 6/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7031 - f1_score: 0.3969 - loss: 0.1202 - val_accuracy: 0.7372 - val_f1_score: 0.3484 - val_loss: 0.1085 - learning_rate: 1.0000e-04
# Epoch 7/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7169 - f1_score: 0.4110 - loss: 0.1132 - val_accuracy: 0.7416 - val_f1_score: 0.3700 - val_loss: 0.1026 - learning_rate: 1.0000e-04
# Epoch 8/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7152 - f1_score: 0.4293 - loss: 0.1090 - val_accuracy: 0.7473 - val_f1_score: 0.3992 - val_loss: 0.1002 - learning_rate: 1.0000e-04
# Epoch 9/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 40s 197ms/step - accuracy: 0.7324 - f1_score: 0.4715 - loss: 0.1038 - val_accuracy: 0.7524 - val_f1_score: 0.4327 - val_loss: 0.0971 - learning_rate: 1.0000e-04
# Epoch 10/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 40s 198ms/step - accuracy: 0.7363 - f1_score: 0.4796 - loss: 0.0986 - val_accuracy: 0.7530 - val_f1_score: 0.4103 - val_loss: 0.0962 - learning_rate: 1.0000e-04
# Epoch 11/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7399 - f1_score: 0.4879 - loss: 0.0969 - val_accuracy: 0.7448 - val_f1_score: 0.4222 - val_loss: 0.0964 - learning_rate: 1.0000e-04
# Epoch 12/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 39s 196ms/step - accuracy: 0.7473 - f1_score: 0.5176 - loss: 0.0921 - val_accuracy: 0.7587 - val_f1_score: 0.4215 - val_loss: 0.0929 - learning_rate: 1.0000e-04
# Epoch 13/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 182ms/step - accuracy: 0.7520 - f1_score: 0.5133 - loss: 0.0902 - val_accuracy: 0.7688 - val_f1_score: 0.4839 - val_loss: 0.0901 - learning_rate: 1.0000e-04
# Epoch 14/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7590 - f1_score: 0.5412 - loss: 0.0887 - val_accuracy: 0.7638 - val_f1_score: 0.4754 - val_loss: 0.0900 - learning_rate: 1.0000e-04
# Epoch 15/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7486 - f1_score: 0.5221 - loss: 0.0873 - val_accuracy: 0.7606 - val_f1_score: 0.4932 - val_loss: 0.0891 - learning_rate: 1.0000e-04
# Epoch 16/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7656 - f1_score: 0.5586 - loss: 0.0839 - val_accuracy: 0.7650 - val_f1_score: 0.4633 - val_loss: 0.0902 - learning_rate: 1.0000e-04
# Epoch 17/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7656 - f1_score: 0.5611 - loss: 0.0830 - val_accuracy: 0.7707 - val_f1_score: 0.4874 - val_loss: 0.0869 - learning_rate: 1.0000e-04
# Epoch 18/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7653 - f1_score: 0.5527 - loss: 0.0819 - val_accuracy: 0.7688 - val_f1_score: 0.4602 - val_loss: 0.0869 - learning_rate: 1.0000e-04
# Epoch 19/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7743 - f1_score: 0.5773 - loss: 0.0807 - val_accuracy: 0.7733 - val_f1_score: 0.4954 - val_loss: 0.0839 - learning_rate: 1.0000e-04
# Epoch 20/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7718 - f1_score: 0.5672 - loss: 0.0797 - val_accuracy: 0.7790 - val_f1_score: 0.4937 - val_loss: 0.0828 - learning_rate: 1.0000e-04
# Epoch 21/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7754 - f1_score: 0.5756 - loss: 0.0768 - val_accuracy: 0.7676 - val_f1_score: 0.4854 - val_loss: 0.0863 - learning_rate: 1.0000e-04
# Epoch 22/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7754 - f1_score: 0.6001 - loss: 0.0770 - val_accuracy: 0.7726 - val_f1_score: 0.4938 - val_loss: 0.0844 - learning_rate: 1.0000e-04
# Epoch 23/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7774 - f1_score: 0.5969 - loss: 0.0747 - val_accuracy: 0.7821 - val_f1_score: 0.5038 - val_loss: 0.0822 - learning_rate: 1.0000e-04
# Epoch 24/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7848 - f1_score: 0.6022 - loss: 0.0744 - val_accuracy: 0.7815 - val_f1_score: 0.4952 - val_loss: 0.0839 - learning_rate: 1.0000e-04
# Epoch 25/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7884 - f1_score: 0.6197 - loss: 0.0722 - val_accuracy: 0.7821 - val_f1_score: 0.5062 - val_loss: 0.0816 - learning_rate: 1.0000e-04
# Epoch 26/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.7896 - f1_score: 0.6270 - loss: 0.0726 - val_accuracy: 0.7745 - val_f1_score: 0.5184 - val_loss: 0.0825 - learning_rate: 1.0000e-04
# Epoch 27/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7852 - f1_score: 0.6114 - loss: 0.0720 - val_accuracy: 0.7764 - val_f1_score: 0.4950 - val_loss: 0.0837 - learning_rate: 1.0000e-04
# Epoch 28/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 178ms/step - accuracy: 0.7882 - f1_score: 0.6286 - loss: 0.0705 - val_accuracy: 0.7802 - val_f1_score: 0.5233 - val_loss: 0.0829 - learning_rate: 1.0000e-04
# Epoch 29/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7954 - f1_score: 0.6421 - loss: 0.0696 - val_accuracy: 0.7752 - val_f1_score: 0.5226 - val_loss: 0.0806 - learning_rate: 1.0000e-04
# Epoch 30/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7937 - f1_score: 0.6366 - loss: 0.0697 - val_accuracy: 0.7707 - val_f1_score: 0.5204 - val_loss: 0.0808 - learning_rate: 1.0000e-04
# Epoch 31/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.7929 - f1_score: 0.6326 - loss: 0.0682 - val_accuracy: 0.7771 - val_f1_score: 0.5164 - val_loss: 0.0823 - learning_rate: 1.0000e-04
# Epoch 32/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7949 - f1_score: 0.6300 - loss: 0.0682 - val_accuracy: 0.7847 - val_f1_score: 0.5088 - val_loss: 0.0817 - learning_rate: 1.0000e-04
# Epoch 33/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 183ms/step - accuracy: 0.7990 - f1_score: 0.6469 - loss: 0.0665 - val_accuracy: 0.7859 - val_f1_score: 0.5141 - val_loss: 0.0799 - learning_rate: 1.0000e-04
# Epoch 34/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8013 - f1_score: 0.6502 - loss: 0.0668 - val_accuracy: 0.7891 - val_f1_score: 0.5180 - val_loss: 0.0815 - learning_rate: 1.0000e-04
# Epoch 35/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7980 - f1_score: 0.6484 - loss: 0.0659 - val_accuracy: 0.7910 - val_f1_score: 0.5265 - val_loss: 0.0800 - learning_rate: 1.0000e-04
# Epoch 36/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7957 - f1_score: 0.6460 - loss: 0.0653 - val_accuracy: 0.7885 - val_f1_score: 0.5213 - val_loss: 0.0798 - learning_rate: 1.0000e-04
# Epoch 37/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8063 - f1_score: 0.6576 - loss: 0.0651 - val_accuracy: 0.7942 - val_f1_score: 0.5350 - val_loss: 0.0798 - learning_rate: 1.0000e-04
# Epoch 38/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.7973 - f1_score: 0.6337 - loss: 0.0647 - val_accuracy: 0.7897 - val_f1_score: 0.5218 - val_loss: 0.0806 - learning_rate: 1.0000e-04
# Epoch 39/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 182ms/step - accuracy: 0.8046 - f1_score: 0.6550 - loss: 0.0636 - val_accuracy: 0.7783 - val_f1_score: 0.5214 - val_loss: 0.0786 - learning_rate: 1.0000e-04
# Epoch 40/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8026 - f1_score: 0.6476 - loss: 0.0639 - val_accuracy: 0.7897 - val_f1_score: 0.5322 - val_loss: 0.0794 - learning_rate: 1.0000e-04
# Epoch 41/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8074 - f1_score: 0.6639 - loss: 0.0642 - val_accuracy: 0.7891 - val_f1_score: 0.5224 - val_loss: 0.0806 - learning_rate: 1.0000e-04
# Epoch 42/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8051 - f1_score: 0.6506 - loss: 0.0637 - val_accuracy: 0.7910 - val_f1_score: 0.5251 - val_loss: 0.0804 - learning_rate: 1.0000e-04
# Epoch 43/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8057 - f1_score: 0.6515 - loss: 0.0624 - val_accuracy: 0.7904 - val_f1_score: 0.5271 - val_loss: 0.0797 - learning_rate: 1.0000e-04
# Epoch 44/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8074 - f1_score: 0.6661 - loss: 0.0620 - val_accuracy: 0.7739 - val_f1_score: 0.5284 - val_loss: 0.0803 - learning_rate: 1.0000e-04
# Epoch 45/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8119 - f1_score: 0.6570 - loss: 0.0622 - val_accuracy: 0.7885 - val_f1_score: 0.5178 - val_loss: 0.0788 - learning_rate: 1.0000e-04
# Epoch 46/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8043 - f1_score: 0.6742 - loss: 0.0620 - val_accuracy: 0.7815 - val_f1_score: 0.5138 - val_loss: 0.0814 - learning_rate: 1.0000e-04
# Epoch 47/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8055 - f1_score: 0.6661 - loss: 0.0617 - val_accuracy: 0.7878 - val_f1_score: 0.5229 - val_loss: 0.0805 - learning_rate: 1.0000e-04
# Epoch 48/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8113 - f1_score: 0.6803 - loss: 0.0598 - val_accuracy: 0.7929 - val_f1_score: 0.5355 - val_loss: 0.0776 - learning_rate: 1.0000e-04
# Epoch 49/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8124 - f1_score: 0.6799 - loss: 0.0598 - val_accuracy: 0.7872 - val_f1_score: 0.5271 - val_loss: 0.0774 - learning_rate: 1.0000e-04
# Epoch 50/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8119 - f1_score: 0.6825 - loss: 0.0600 - val_accuracy: 0.7929 - val_f1_score: 0.5432 - val_loss: 0.0779 - learning_rate: 1.0000e-04
# Epoch 51/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 39s 196ms/step - accuracy: 0.8100 - f1_score: 0.6708 - loss: 0.0599 - val_accuracy: 0.7897 - val_f1_score: 0.5258 - val_loss: 0.0781 - learning_rate: 1.0000e-04
# Epoch 52/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8118 - f1_score: 0.6692 - loss: 0.0593 - val_accuracy: 0.7897 - val_f1_score: 0.5240 - val_loss: 0.0785 - learning_rate: 1.0000e-04
# Epoch 53/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8107 - f1_score: 0.6883 - loss: 0.0587 - val_accuracy: 0.7885 - val_f1_score: 0.5247 - val_loss: 0.0809 - learning_rate: 1.0000e-04
# Epoch 54/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8113 - f1_score: 0.6814 - loss: 0.0598 - val_accuracy: 0.7853 - val_f1_score: 0.5327 - val_loss: 0.0790 - learning_rate: 1.0000e-04
# Epoch 55/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8147 - f1_score: 0.6890 - loss: 0.0585 - val_accuracy: 0.7796 - val_f1_score: 0.5193 - val_loss: 0.0792 - learning_rate: 1.0000e-04
# Epoch 56/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8135 - f1_score: 0.6724 - loss: 0.0586 - val_accuracy: 0.7961 - val_f1_score: 0.5421 - val_loss: 0.0780 - learning_rate: 1.0000e-04
# Epoch 57/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 178ms/step - accuracy: 0.8153 - f1_score: 0.6879 - loss: 0.0576 - val_accuracy: 0.7961 - val_f1_score: 0.5371 - val_loss: 0.0792 - learning_rate: 1.0000e-04
# Epoch 58/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 182ms/step - accuracy: 0.8111 - f1_score: 0.6841 - loss: 0.0598 - val_accuracy: 0.7866 - val_f1_score: 0.5286 - val_loss: 0.0788 - learning_rate: 1.0000e-04
# Epoch 59/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8334 - f1_score: 0.7023 - loss: 0.0556
# Epoch 59: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8213 - f1_score: 0.6961 - loss: 0.0571 - val_accuracy: 0.7948 - val_f1_score: 0.5420 - val_loss: 0.0780 - learning_rate: 1.0000e-04
# Epoch 60/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8231 - f1_score: 0.7075 - loss: 0.0561 - val_accuracy: 0.7986 - val_f1_score: 0.5350 - val_loss: 0.0788 - learning_rate: 5.0000e-05
# Epoch 61/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8210 - f1_score: 0.7022 - loss: 0.0573 - val_accuracy: 0.7992 - val_f1_score: 0.5434 - val_loss: 0.0775 - learning_rate: 5.0000e-05
# Epoch 62/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8199 - f1_score: 0.7027 - loss: 0.0567 - val_accuracy: 0.8011 - val_f1_score: 0.5571 - val_loss: 0.0765 - learning_rate: 5.0000e-05
# Epoch 63/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8235 - f1_score: 0.7139 - loss: 0.0568 - val_accuracy: 0.7904 - val_f1_score: 0.5357 - val_loss: 0.0787 - learning_rate: 5.0000e-05
# Epoch 64/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8230 - f1_score: 0.7109 - loss: 0.0559 - val_accuracy: 0.7904 - val_f1_score: 0.5379 - val_loss: 0.0775 - learning_rate: 5.0000e-05
# Epoch 65/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8194 - f1_score: 0.7035 - loss: 0.0561 - val_accuracy: 0.7796 - val_f1_score: 0.5426 - val_loss: 0.0786 - learning_rate: 5.0000e-05
# Epoch 66/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8194 - f1_score: 0.7041 - loss: 0.0561 - val_accuracy: 0.7796 - val_f1_score: 0.5285 - val_loss: 0.0801 - learning_rate: 5.0000e-05
# Epoch 67/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8186 - f1_score: 0.6897 - loss: 0.0563 - val_accuracy: 0.7847 - val_f1_score: 0.5383 - val_loss: 0.0779 - learning_rate: 5.0000e-05
# Epoch 68/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8256 - f1_score: 0.7152 - loss: 0.0558 - val_accuracy: 0.7847 - val_f1_score: 0.5345 - val_loss: 0.0788 - learning_rate: 5.0000e-05
# Epoch 69/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8236 - f1_score: 0.7080 - loss: 0.0550 - val_accuracy: 0.7897 - val_f1_score: 0.5389 - val_loss: 0.0781 - learning_rate: 5.0000e-05
# Epoch 70/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8260 - f1_score: 0.7233 - loss: 0.0549 - val_accuracy: 0.7967 - val_f1_score: 0.5359 - val_loss: 0.0776 - learning_rate: 5.0000e-05
# Epoch 71/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8244 - f1_score: 0.7024 - loss: 0.0548 - val_accuracy: 0.7809 - val_f1_score: 0.5301 - val_loss: 0.0794 - learning_rate: 5.0000e-05
# Epoch 72/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8330 - f1_score: 0.7202 - loss: 0.0535
# Epoch 72: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8283 - f1_score: 0.7118 - loss: 0.0549 - val_accuracy: 0.7967 - val_f1_score: 0.5392 - val_loss: 0.0780 - learning_rate: 5.0000e-05
# Epoch 73/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.8260 - f1_score: 0.7165 - loss: 0.0540 - val_accuracy: 0.7916 - val_f1_score: 0.5436 - val_loss: 0.0783 - learning_rate: 2.5000e-05
# Epoch 74/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8253 - f1_score: 0.7126 - loss: 0.0552 - val_accuracy: 0.7847 - val_f1_score: 0.5386 - val_loss: 0.0783 - learning_rate: 2.5000e-05
# Epoch 75/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 180ms/step - accuracy: 0.8249 - f1_score: 0.7052 - loss: 0.0544 - val_accuracy: 0.7986 - val_f1_score: 0.5453 - val_loss: 0.0774 - learning_rate: 2.5000e-05
# Epoch 76/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 41s 181ms/step - accuracy: 0.8284 - f1_score: 0.7174 - loss: 0.0541 - val_accuracy: 0.7948 - val_f1_score: 0.5391 - val_loss: 0.0780 - learning_rate: 2.5000e-05
# Epoch 77/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8244 - f1_score: 0.7031 - loss: 0.0556 - val_accuracy: 0.7973 - val_f1_score: 0.5413 - val_loss: 0.0775 - learning_rate: 2.5000e-05
# Epoch 78/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 178ms/step - accuracy: 0.8297 - f1_score: 0.7131 - loss: 0.0531 - val_accuracy: 0.7986 - val_f1_score: 0.5459 - val_loss: 0.0777 - learning_rate: 2.5000e-05
# Epoch 79/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8255 - f1_score: 0.7044 - loss: 0.0550 - val_accuracy: 0.7954 - val_f1_score: 0.5460 - val_loss: 0.0773 - learning_rate: 2.5000e-05
# Epoch 80/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8269 - f1_score: 0.7198 - loss: 0.0550 - val_accuracy: 0.7910 - val_f1_score: 0.5370 - val_loss: 0.0786 - learning_rate: 2.5000e-05
# Epoch 81/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8258 - f1_score: 0.7088 - loss: 0.0535 - val_accuracy: 0.7961 - val_f1_score: 0.5428 - val_loss: 0.0782 - learning_rate: 2.5000e-05
# Epoch 82/100
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8311 - f1_score: 0.7289 - loss: 0.0533
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.8322 - f1_score: 0.7229 - loss: 0.0529 - val_accuracy: 0.7840 - val_f1_score: 0.5361 - val_loss: 0.0782 - learning_rate: 2.5000e-05
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 62.

# %%
print_results(model, test_generator, list(leison_type_index_mapping.values()))
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 178ms/step
#                                precision    recall  f1-score   support
#
#             Actinic keratoses       0.67      0.43      0.53        67
#          Basal cell carcinoma       0.53      0.39      0.45        90
# Benign keratosis-like lesions       0.61      0.61      0.61       243
#                Dermatofibroma       0.45      0.28      0.34        18
#              Melanocytic nevi       0.87      0.91      0.89      1336
#                      Melanoma       0.51      0.53      0.52       236
#              Vascular lesions       0.82      0.41      0.55        34
#
#                      accuracy                           0.78      2024
#                     macro avg       0.64      0.51      0.56      2024
#                  weighted avg       0.77      0.78      0.77      2024

# %%
model.save("transfer_learning_cnn_model.keras")

# %% [markdown]
# <small> Для продолжения работы после ряда численных экспериментов с другими нейронными сетями было принято решение использовать перенос обучения из ResNet-50 - сверточной нейронной сети глубиной 50 слоев, созданной в 2015 году. На первом этапе обучался лишь собственный классификатор. Реализация данного подхода позволила существенно улучшить качество классификации для редких классов. В частности, f1 для опасных меланом и базальноклеточных карцином вырос до 0,52 и 0,45, а общий f1 увеличился до 0,56.</small>

# %% [markdown]
# Модель CNN с переносом обучения и fine-tuning:

# %%
base_model.trainable = True

# %%
model.compile(optimizer=Adam(learning_rate=0.00001), loss=keras.losses.CategoricalFocalCrossentropy(), metrics=['f1_score', "accuracy"])

# %%
callbacks_fine_tuning = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-7, verbose=1)
]

# %%
model.fit(
    train_generator,
    validation_data=val_generator,
    batch_size=32,
    epochs=20,
    callbacks=callbacks_fine_tuning,
    verbose=1
)
# Out:
# Epoch 1/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 168s 632ms/step - accuracy: 0.7152 - f1_score: 0.4512 - loss: 0.1252 - val_accuracy: 0.7752 - val_f1_score: 0.4928 - val_loss: 0.1022 - learning_rate: 1.0000e-05
# Epoch 2/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 604ms/step - accuracy: 0.7681 - f1_score: 0.5893 - loss: 0.0849 - val_accuracy: 0.7739 - val_f1_score: 0.5113 - val_loss: 0.0901 - learning_rate: 1.0000e-05
# Epoch 3/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 122s 605ms/step - accuracy: 0.7929 - f1_score: 0.6616 - loss: 0.0689 - val_accuracy: 0.7802 - val_f1_score: 0.5492 - val_loss: 0.0818 - learning_rate: 1.0000e-05
# Epoch 4/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 603ms/step - accuracy: 0.8065 - f1_score: 0.6949 - loss: 0.0605 - val_accuracy: 0.7923 - val_f1_score: 0.5532 - val_loss: 0.0787 - learning_rate: 1.0000e-05
# Epoch 5/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 603ms/step - accuracy: 0.8300 - f1_score: 0.7390 - loss: 0.0519 - val_accuracy: 0.7992 - val_f1_score: 0.5756 - val_loss: 0.0781 - learning_rate: 1.0000e-05
# Epoch 6/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 603ms/step - accuracy: 0.8376 - f1_score: 0.7449 - loss: 0.0493 - val_accuracy: 0.7942 - val_f1_score: 0.5726 - val_loss: 0.0775 - learning_rate: 1.0000e-05
# Epoch 7/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 601ms/step - accuracy: 0.8475 - f1_score: 0.7686 - loss: 0.0442 - val_accuracy: 0.7948 - val_f1_score: 0.5700 - val_loss: 0.0782 - learning_rate: 1.0000e-05
# Epoch 8/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 603ms/step - accuracy: 0.8629 - f1_score: 0.7911 - loss: 0.0389 - val_accuracy: 0.8132 - val_f1_score: 0.6151 - val_loss: 0.0750 - learning_rate: 1.0000e-05
# Epoch 9/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 602ms/step - accuracy: 0.8759 - f1_score: 0.8192 - loss: 0.0364 - val_accuracy: 0.8062 - val_f1_score: 0.6038 - val_loss: 0.0774 - learning_rate: 1.0000e-05
# Epoch 10/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.8769 - f1_score: 0.8263 - loss: 0.0339
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 602ms/step - accuracy: 0.8799 - f1_score: 0.8252 - loss: 0.0324 - val_accuracy: 0.8056 - val_f1_score: 0.6254 - val_loss: 0.0751 - learning_rate: 1.0000e-05
# Epoch 11/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 603ms/step - accuracy: 0.8872 - f1_score: 0.8354 - loss: 0.0305 - val_accuracy: 0.8138 - val_f1_score: 0.6161 - val_loss: 0.0730 - learning_rate: 5.0000e-06
# Epoch 12/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 602ms/step - accuracy: 0.9033 - f1_score: 0.8517 - loss: 0.0270 - val_accuracy: 0.8132 - val_f1_score: 0.6216 - val_loss: 0.0752 - learning_rate: 5.0000e-06
# Epoch 13/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.8976 - f1_score: 0.8568 - loss: 0.0270
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 602ms/step - accuracy: 0.8977 - f1_score: 0.8597 - loss: 0.0264 - val_accuracy: 0.8176 - val_f1_score: 0.6258 - val_loss: 0.0745 - learning_rate: 5.0000e-06
# Epoch 14/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 602ms/step - accuracy: 0.9114 - f1_score: 0.8756 - loss: 0.0237 - val_accuracy: 0.8049 - val_f1_score: 0.6160 - val_loss: 0.0743 - learning_rate: 2.5000e-06
# Epoch 15/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.9052 - f1_score: 0.8558 - loss: 0.0230
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 601ms/step - accuracy: 0.9081 - f1_score: 0.8686 - loss: 0.0232 - val_accuracy: 0.8081 - val_f1_score: 0.6171 - val_loss: 0.0750 - learning_rate: 2.5000e-06
# Epoch 16/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 121s 603ms/step - accuracy: 0.9147 - f1_score: 0.8832 - loss: 0.0226 - val_accuracy: 0.8119 - val_f1_score: 0.6163 - val_loss: 0.0753 - learning_rate: 1.2500e-06
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %%
print_results(model, test_generator, list(leison_type_index_mapping.values()))
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step
#                                precision    recall  f1-score   support
#
#             Actinic keratoses       0.64      0.40      0.50        67
#          Basal cell carcinoma       0.72      0.56      0.63        90
# Benign keratosis-like lesions       0.67      0.69      0.68       243
#                Dermatofibroma       0.36      0.44      0.40        18
#              Melanocytic nevi       0.90      0.90      0.90      1336
#                      Melanoma       0.51      0.60      0.55       236
#              Vascular lesions       0.88      0.62      0.72        34
#
#                      accuracy                           0.80      2024
#                     macro avg       0.67      0.60      0.63      2024
#                  weighted avg       0.80      0.80      0.80      2024

# %% [markdown]
# <small> На втором этапе предпринята попытка полного дообучения. Размораживались все слои сети, но обучение шло с очень маленьким шагом (0,00001). В результате общий f1 вырос до 0,63 в основном за счет улучшения классификации для редких классов. Для опасных меланом f1 увеличился до 0,55. Для базальноклеточных карцином отмечен более значительный рост - до 0,63.</small>

# %%
model.save("fine_tuning_cnn_model.keras")

# %% [markdown]
# Вывод: в ходе работы исследована возможность применения сверточных нейронных сетей для определения типов поражения кожи по изображению. Рассмотрена простая нейронная сеть, а также нейронная сеть на основе переноса обучения из ResNet-50. Лучшая модель на основе полного дообучения ResNet-50 показала средний f1 0.63, однако для опасных классов (меланома и базальноклеточная карцинома) полнота осталась на уровне 0,60 и 0,56 соответственно. Таким образом, на данном этапе разработанная модель демонстрирует недостаточный уровень точности для решения медицинской задачи классификации поражений кожи, где критически важно корректное определение редких опасных классов. Однако рост точности от простых к более сложным моделям показывает глубокий потенциал нейронных сетей для решения подобных задач. Существуют возможности для повышения точности путем использования более сложных архитектур, например, трансформеров.
